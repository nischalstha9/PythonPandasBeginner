# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/DateTime.csv')

# %%
df.set_index('Date', inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df.sort_values(by='Date', ascending=False)
# Out:
#                    Date  Symbol    Open    High     Low   Close       Volume
# 8      2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 20     2020-03-13 12-AM  ETHUSD  110.30  117.50  102.92  107.09  10329663.69
# 9      2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 10     2020-03-13 10-AM  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# 11     2020-03-13 09-AM  ETHUSD  127.12  136.53  126.62  133.80   2767584.44
# ...                 ...     ...     ...     ...     ...     ...          ...
# 23667  2017-07-01 05-PM  ETHUSD  268.00  268.44  262.39  263.51   1894983.33
# 23668  2017-07-01 04-PM  ETHUSD  272.57  272.57  267.60  268.00   1287300.75
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57   1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74   1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79   3010787.99
#
# [23674 rows x 7 columns]

# %%
df['Symbol'].value_counts()
# Out:
# ETHUSD    23674
# Name: Symbol, dtype: int64

# %%
df['Date'] =pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')#now we have converted string to formatted date time

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
help(df.loc[0,'Date'])
# Out:
# Help on Timestamp in module pandas._libs.tslibs.timestamps object:
#
# class Timestamp(_Timestamp)
#  |  Timestamp(ts_input=<object object at 0x7f4cf7d49800>, freq=None, tz=None, unit=None, year=None, month=None, day=None, hour=None, minute=None, second=None, microsecond=None, nanosecond=None, tzinfo=None, *, fold=None)
#  |
#  |  Pandas replacement for python datetime.datetime object.
#  |
#  |  Timestamp is the pandas equivalent of python's Datetime
#  |  and is interchangeable with it in most cases. It's the type used
#  |  for the entries that make up a DatetimeIndex, and other timeseries
#  |  oriented data structures in pandas.
#  |
#  |  Parameters
#  |  ----------
#  |  ts_input : datetime-like, str, int, float
#  |      Value to be converted to Timestamp.
#  |  freq : str, DateOffset
#  |      Offset which Timestamp will have.
#  |  tz : str, pytz.timezone, dateutil.tz.tzfile or None
#  |      Time zone for time which Timestamp will have.
#  |  unit : str
# ...

# %%
df.loc[80,'Date'].day_name()
# Out:
# 'Tuesday'

# %% [markdown]
# ##### We can also convert to date time during CSV import

# %%
from datetime import datetime
df_dateV=pd.read_csv('data/DateTime.csv', parse_dates=['Date'], date_parser=lambda x: datetime.strptime(x,'%Y-%m-%d %I-%p'))

# %%
df_dateV#here we have already converted to datetme DateFrame Object
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['dayOfWeek']=df['Date'].dt.day_name()

# %%
help(df['Date'].dt)
# Out:
# Help on DatetimeProperties in module pandas.core.indexes.accessors object:
#
# class DatetimeProperties(Properties)
#  |  DatetimeProperties(data: 'Series', orig)
#  |
#  |  Accessor object for datetimelike properties of the Series values.
#  |
#  |  Examples
#  |  --------
#  |  >>> seconds_series = pd.Series(pd.date_range("2000-01-01", periods=3, freq="s"))
#  |  >>> seconds_series
#  |  0   2000-01-01 00:00:00
#  |  1   2000-01-01 00:00:01
#  |  2   2000-01-01 00:00:02
#  |  dtype: datetime64[ns]
#  |  >>> seconds_series.dt.second
#  |  0    0
#  |  1    1
#  |  2    2
#  |  dtype: int64
#  |
#  |  >>> hours_series = pd.Series(pd.date_range("2000-01-01", periods=3, freq="h"))
#  |  >>> hours_series
#  |  0   2000-01-01 00:00:00
#  |  1   2000-01-01 01:00:00
#  |  2   2000-01-01 02:00:00
#  |  dtype: datetime64[ns]
#  |  >>> hours_series.dt.hour
#  |  0    0
#  |  1    1
#  |  2    2
#  |  dtype: int64
#  |
# ...

# %%
#df.drop('DayOfWeek',axis=1,inplace=True)#dropped

# %%
df['Month']=df['Date'].dt.month_name()

# %%
df['Year']=df['Date'].dt.year

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max()-df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %% [markdown]
# #### Filtering with DateTime

# %%
filtr=(df['Date'] >= '2019')&(df['Date'] <= '2020')

# %%
df.loc[filtr]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1748  2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#        dayOfWeek     Month  Year
# ...

# %%
df.set_index('Date', inplace=True)

# %% [markdown]
# ###  Slicing in Date Data Frame

# %%
df.loc['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      dayOfWeek     Month  Year
# Date
# ...

# %%
df.loc['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df.loc['2020-01-01']['High'].describe()
# Out:
# count     24.000000
# mean     131.011250
# std        1.063498
# min      128.540000
# 25%      130.242500
# 50%      130.905000
# 75%      132.005000
# max      132.680000
# Name: High, dtype: float64

# %%
high_d = df['High'].resample('D').max()

# %%
high_d['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
high_d.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
#               Year
# Date
# 2017-07-02  2017.0
# 2017-07-09  2017.0
# ...

# %%
Monthly_Ananlysis = df.resample('M').agg({'Open':'mean','Close':'mean','Low':'min','High':'max','Volume':'sum'})

# %%
Monthly_Ananlysis
# Out:
#                    Open        Close     Low     High        Volume
# Date
# 2017-07-31   220.118963   220.010969  130.26   293.73  1.818282e+09
# 2017-08-31   298.258616   298.511815  200.82   392.00  1.529929e+09
# 2017-09-30   298.656472   298.524639  202.25   396.88  1.678947e+09
# 2017-10-31   305.642594   305.649772  275.46   350.00  8.155377e+08
# 2017-11-30   355.471236   355.646292  278.88   518.13  1.974056e+09
# 2017-12-31   629.484960   629.898011  415.01   875.00  5.172910e+09
# 2018-01-31  1083.552487  1084.040390  727.14  1419.96  7.728885e+09
# 2018-02-28   872.477783   872.098304  555.56  1143.00  4.123206e+09
# 2018-03-31   630.316505   629.704341  365.00   878.00  2.028503e+09
# 2018-04-30   515.700625   516.082944  360.00   711.00  1.899357e+09
# 2018-05-31   676.451909   676.327298  507.00   828.97  2.241083e+09
# 2018-06-30   519.966306   519.794347  404.22   627.83  1.254270e+09
# 2018-07-31   461.867298   461.838898  418.23   515.88  7.496308e+08
# ...
