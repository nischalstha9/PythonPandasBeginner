# %%
import pandas as pd #importing pandaas
df = pd.read_csv('data/survey_results_public.csv') # importing csv as data frame
schema_df = pd.read_csv('data/survey_results_schema.csv') # importing schema_csv as data frame_schema
pd.set_option('display.max_columns',85)#option to view all columns in dataframe
pd.set_option('display.max_rows',85)#option to view all rows in dataframe
df.set_index('Respondent', inplace=True)
schema_df.set_index(('Column'), inplace=True) #inplace makes indexing permanent

# %%
filtr = (df['Country']=='Nepal')&(df['LanguageWorkedWith'].str.contains('Python'))

# %%
Nepal_df = df[filtr]

# %%
Nepal_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 592                 I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# 1858                I am a developer by profession      Yes
# 1896                I am a developer by profession      Yes
# 2436        I am a student who is learning to code      Yes
# ...                                            ...      ...
# 85446               I am a developer by profession      Yes
# 86087               I am a developer by profession      Yes
# 86618               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 592                                                     Never
# 1783        Less than once a month but more than once per ...
# ...

# %%
Nepal_df.to_csv('data/Nepal_StackOverFlow_knows_Python.csv')

# %%
Nepal_df.to_csv('data/Nepal_StackOverFlow_knows_Python.tsv', sep='\t')#tsv is Tab Seperated Values, sep='\t' is required for reading TSV files

# %%
Nepal_df.to_json('data/Nepal_StackOverFlow_knows_Python.json')

# %% [markdown]
# #### orients keeps data in row method #pd.read_json to read json also mention orient

# %%
Nepal_df.to_json('data/Nepal_StackOverFlow_knows_Python.json', orient='records')

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine=create_engine('postgresql://postgres:admin@localhost:5433/STACK_OVFLOW')#connection SQL Alchemy to Postgres

# %%
Nepal_df.to_sql('sample_table', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
connection = psycopg2.connect(database="STACK_OVFLOW", user="admin", host="localhost", password="admin")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-79-2efa141db2e4> in <module>
# ----> 1 connection = psycopg2.connect(database="STACK_OVFLOW", user="admin", host="localhost", password="admin")
#
# ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  password authentication failed for user "admin"
# FATAL:  password authentication failed for user "admin"

# %%
#pd.read_sql('sample_table', engine, index_column = 'Respondent')

# %%
#pd.read_sql_query('SELECT * FROM sample_table', engine, index_column = 'Respondent')
